# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_addons as tfa
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from catboost import CatBoostClassifier

# %%
train = pd.read_csv('../Data/train_values.csv', index_col='building_id')
labels = pd.read_csv('../Data/train_labels.csv', index_col='building_id')
test = pd.read_csv('../Data/test_values.csv', index_col='building_id')

# %%
train.dtypes
# Out:
# geo_level_1_id                             int64
# geo_level_2_id                             int64
# geo_level_3_id                             int64
# count_floors_pre_eq                        int64
# age                                        int64
# area_percentage                            int64
# height_percentage                          int64
# land_surface_condition                    object
# foundation_type                           object
# roof_type                                 object
# ground_floor_type                         object
# other_floor_type                          object
# position                                  object
# plan_configuration                        object
# has_superstructure_adobe_mud               int64
# has_superstructure_mud_mortar_stone        int64
# has_superstructure_stone_flag              int64
# has_superstructure_cement_mortar_stone     int64
# has_superstructure_mud_mortar_brick        int64
# has_superstructure_cement_mortar_brick     int64
# has_superstructure_timber                  int64
# has_superstructure_bamboo                  int64
# has_superstructure_rc_non_engineered       int64
# has_superstructure_rc_engineered           int64
# has_superstructure_other                   int64
# legal_ownership_status                    object
# count_families                             int64
# has_secondary_use                          int64
# has_secondary_use_agriculture              int64
# has_secondary_use_hotel                    int64
# has_secondary_use_rental                   int64
# has_secondary_use_institution              int64
# has_secondary_use_school                   int64
# has_secondary_use_industry                 int64
# has_secondary_use_health_post              int64
# has_secondary_use_gov_office               int64
# has_secondary_use_use_police               int64
# has_secondary_use_other                    int64
# dtype: object

# %%
cat_cols = list(train.select_dtypes('object').columns)

bin_cols = [
    'has_superstructure_adobe_mud',
    'has_superstructure_mud_mortar_stone',
    'has_superstructure_stone_flag',
    'has_superstructure_cement_mortar_stone',
    'has_superstructure_mud_mortar_brick',
    'has_superstructure_cement_mortar_brick',
    'has_superstructure_timber',
    'has_superstructure_rc_engineered',
    'has_superstructure_other',
    'has_secondary_use',
    'has_secondary_use_agriculture',
    'has_secondary_use_hotel',
    'has_secondary_use_rental',
    'has_secondary_use_institution',
    'has_secondary_use_school',
    'has_secondary_use_industry',
    'has_secondary_use_health_post',
    'has_secondary_use_gov_office',
    'has_secondary_use_use_police',
    'has_secondary_use_other'
]

all_cat_cols = cat_cols + bin_cols

num_cols = list(train.select_dtypes('number').columns)

# %%
ct = ColumnTransformer(
#    [('cat', OneHotEncoder(), all_cat_cols),
    [('num', StandardScaler(), num_cols)
    ],
    remainder='passthrough')

# %%
train_enc = ct.fit_transform(train)

# %%
labels_encoder = OneHotEncoder()
labels_enc = labels_encoder.fit_transform(np.array(labels).reshape(-1,1))
labels_enc = labels_enc.toarray()

# %%
categorical_features_indices = np.where((train_enc != np.float))[0]

# %%
categorical_features_indices = np.asarray([int(train.columns.get_loc(c)) for c in all_cat_cols])

# %%
# Out:
# array([[-0.9834136903330413, -0.5187049387843586, 1.6290546017011027,
#         ..., 't', 'd', 'v'],
#        [-0.7344593363138063, 0.48199787510963743, -0.9450173995037939,
#         ..., 's', 'd', 'v'],
#        [0.8837439648112211, -0.8191580838760184, 0.7446115797656891, ...,
#         't', 'd', 'v'],
#        ...,
#        [0.3858352567727511, -1.5751369650743883, 0.5224724021633063, ...,
#         's', 'd', 'v'],
#        [1.5061298498593085, -1.6042130758897102, -1.2085677077456334,
#         ..., 'j', 'd', 'v'],
#        [0.8837439648112211, -1.676903352928015, 0.7797150547448312, ...,
#         'j', 'd', 'v']], dtype=object)

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(train_enc, labels, test_size=0.3, random_state=42, shuffle=True)

# %%
sfs = SFS(CatBoostClassifier(n_estimators=100, verbose=False),
          k_features = X_train.shape[1],
          forward=True,
          floating=False,
          verbose=2,
          scoring='f1_micro',
          cv=2)

sfs = sfs.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.5s remaining:    0.0s
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'i'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="i": Cannot convert 'b'i'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'r'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="r": Cannot convert 'b'r'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'x'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="x": Cannot convert 'b'x'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'n'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="n": Cannot convert 'b'n'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'v'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="v": Cannot convert 'b'v'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'f'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="f": Cannot convert 'b'f'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'j'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="j": Cannot convert 'b'j'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'q'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="q": Cannot convert 'b'q'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b's'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="s": Cannot convert 'b's'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'd'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="d": Cannot convert 'b'd'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b'v'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="v": Cannot convert 'b'v'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  1.4min finished
# C:\Users\mcand\Anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
#
# [2021-07-08 17:56:45] Features: 1/38 -- score: nan[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=29]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=29]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=28]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.2s finished
# C:\Users\mcand\Anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
#
# [2021-07-08 18:02:20] Features: 36/38 -- score: nan[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=30]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=29]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.2s finished
# C:\Users\mcand\Anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
#
# [2021-07-08 18:02:23] Features: 37/38 -- score: nan[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2149, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1122, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 948, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'b't'' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 4673, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1978, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1864, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1151, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 617, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "C:\Users\mcand\Anaconda3\lib\site-packages\catboost\core.py", line 1133, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#   File "_catboost.pyx", line 3721, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3782, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 3696, in _catboost._PoolBase._init_objects_order_layout_pool
#   File "_catboost.pyx", line 3241, in _catboost._set_data
#   File "_catboost.pyx", line 3224, in _catboost._set_data_from_generic_matrix
#   File "_catboost.pyx", line 2151, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=30]="t": Cannot convert 'b't'' to float
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# C:\Users\mcand\Anaconda3\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:612: RuntimeWarning: Mean of empty slice
#   all_avg_scores.append(np.nanmean(cv_scores))
#
# [2021-07-08 18:02:24] Features: 38/38 -- score: nan

# %%
model = keras.Sequential([
    keras.layers.Dense(108, activation='relu'),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(3, activation='relu')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tfa.metrics.F1Score(num_classes=3), 'accuracy'])

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=200,
    epochs=150,
    validation_data=(X_test, y_test),
    #callbacks=[h1n1_mc, EarlyStopping],
    shuffle=True,
    verbose=1
)
